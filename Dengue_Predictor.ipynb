# %% [markdown]
# # Dengue in Singapore: A Predictive Model for NEA

# %%
# Imports
import os
import re
from typing import Dict
from datetime import datetime
from IPython.display import Image

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import seaborn as sns
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import xgboost as xgb
import warnings

# Suppress deprecation warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Table of Contents
#
# 1. [Executive Summary](#Executive-Summary)
# 2. [Approach](#Approach)
# 3. [Data Compilation](#Data-Compilation)
#    1. [Dengue](#Data---Dengue)
#    2. [Weather](#Data---Weather)
#    3. [Google Trends](#Data---Google-Trends)
#    4. [Wolbachia and External Events](#Data---Wolbachia-and-External-Events)
#    5. [Compiled Dataset](#Compiled-Dataset)
# 4. [Forecast Models](#Forecast-Models)
#     1. [ARIMA/SARIMAX](#ARIMA/SARIMAX)
#     2. [Pre- and Post-processing for Tabular Techniques](#Pre--and-Post-processing-for-Tabular-Techniques)
#     3. [Linear Regression](#Linear-Regression)
#     4. [XGBoost](#XGBoost)
# 5. [XGBoost Model Refinement](#XGBoost-Model-Refinement)
# 6. [Wolbachia Effectiveness Investigation](#Wolbachia-Effectiveness-Investigation)
# 7. [Conclusion and Future Work](#Conclusion-and-Future-Work)

# %% [markdown]
# ## Executive Summary
#
# Dengue fever, transmitted by Aedes mosquitoes, is a significant health issue in Singapore. The National Environment Agency (NEA) combats dengue through initiatives like the BLOCK strategy, which eliminates mosquito breeding sites, and the Wolbachia project, releasing male mosquitoes that prevent eggs from hatching. A predictive model using weather data, Google search trends, and other external events can enhance NEA's dengue management by forecasting weekly case counts over an 8-week window. Linear regression, SARIMAX, and XGBoost are employed in this project to provide accurate forecasts, helping NEA allocate resources and implement preventive measures effectively. Of these, XGBoost is found to perform best and used for further investigation into the efficacy of the Wolbachia Project.

# %% [markdown]
# ## Approach
#
# The dengue fever forecast model presented herein is trained on a dataset comprising dengue fever records, historical weather conditions, NEA's combat against dengue, external factors like COVID-related lockdowns and increased construction activity, etc. The dataset is compiled using data from various sources including scraped data from [weather.gov](http://www.weather.gov.sg/climate-historical-daily/), [data.gov](https://data.gov.sg/), [NEA](https://www.nea.gov.sg/), etc. Additional data is gathered through desk research to quantify Wolbachia efforts by determining the proportion of Singaporean estates where male Wolbachia-Aedes mosquitoes are released. The impact of COVID-19 related restrictions and subsequent increased post-lockdown construction activity, both of which have influenced dengue cases, is also considered. Details of the data-gathering process is provided in the accompanying notebook `dengue_scraper.ipynb` in the `data` subdirectory.
#
# This notebook outlines the development of models using techniques such as linear regression, SARIMAX, and XGBoost to understand the factors driving dengue cases and plan effective interventions. An evaluation of these models to compare their performance is included to determine the most suitable approach for the task.

# %% [markdown]
# ## Data Compilation

# %% [markdown]
# Loading all data for cleaning and compiling. We consider data from 2012 to present (i.e. July 2024) for this project.

# %%
datapath = r'./assets/'

# Dengue
df_dengue_datagov_raw = pd.read_csv(os.path.join(datapath,'datagov_dengue.csv'))
df_dengue_jao_raw = pd.read_csv(os.path.join(datapath,'jao_dengue.csv'))
df_dengue_NEA_raw = pd.read_csv(os.path.join(datapath,'NEA_dengue.csv'))

# Weather
# df_weather_datagov_raw = pd.read_csv(os.path.join(datapath,'datagov_weather.csv'))
df_weather_NEA_raw = pd.read_csv(os.path.join(datapath,'NEA_weather.csv'))
df_weather_datagov_RH_raw = pd.read_csv(os.path.join(datapath,'datagov_RH.csv'))

# Google trend
df_trend_dengue_raw = pd.read_csv(os.path.join(datapath,'google_trend_dengue.csv'))
df_trend_dengue_symptoms_raw = pd.read_csv(os.path.join(datapath,'google_trend_dengue_symptoms.csv'))
df_trend_fever_raw = pd.read_csv(os.path.join(datapath,'google_trend_fever.csv'))
df_trend_mosquito_raw = pd.read_csv(os.path.join(datapath,'google_trend_mosquito.csv'))

# Wolbachia
df_wolbachia_raw = pd.read_csv(os.path.join(datapath,'wolbachia_ratio.csv'))

# %% [markdown]
# ### Data - Dengue

# %% [markdown]
# We first clean and compile the available __dengue__ data. Most years have 52 or 53 weeks, while 2024 only has 27 weeks so far. 2019 has some missing entries which will require some imputation later.

# %%
# Clean and compile dengue data
df_dengue_datagov = df_dengue_datagov_raw.copy()
df_dengue_datagov.rename(columns={'year':'Year','eweek':'Week','number':'Dengue_Count'}, inplace=True)    # Rename columns for consistency
df_dengue_datagov = df_dengue_datagov.groupby(['Year','Week']).sum()                                      # Combine normal dengue cases and hemorrhagic cases
df_dengue_datagov = df_dengue_datagov.drop(columns='type_dengue').reset_index()                           # Drop dengue fever type

df_dengue_jao = df_dengue_jao_raw.copy()
df_dengue_jao.rename(columns={'Week No.':'Week', 'Dengue (Count)':'Dengue_Count'},inplace=True)           # Rename columns for consistency
df_dengue_jao.drop(columns=['Daily Rainfall Total (mm)','Mean Temperature (C)'],inplace=True)

df_dengue_NEA = df_dengue_NEA_raw.copy()
df_dengue_NEA = df_dengue_NEA.reset_index()
df_dengue_NEA.drop(columns='Unnamed: 0',inplace=True)
df_dengue_NEA = pd.melt(df_dengue_NEA, id_vars=['index','week'],
                        value_vars=['2020','2021','2022','2023','2024'],
                        var_name='Year', value_name='Dengue_Count')                                       # Gathering into long format for consistency
df_dengue_NEA.drop(columns=['index'],inplace=True)
df_dengue_NEA.rename(columns={'week':'Week'},inplace=True)                                                # Rename columns for consistency

df_dengue = pd.concat([df_dengue_datagov,df_dengue_NEA,df_dengue_jao],axis=0)                             # Compiling all dengue datasets into single dataframe
df_dengue.dropna(inplace=True)                                                                            # Dropping small number of missing values
df_dengue = df_dengue.astype({'Year':'int', 'Dengue_Count':'int'})                                        # Converting to standard dtypes
df_dengue.drop_duplicates(subset=['Year','Week'],inplace=True)                                            # Dropping duplicate entries from different data sources
df_dengue.sort_values(by=['Year','Week'],inplace=True)                                                    # Sort in chronological order
df_dengue.groupby(['Year']).count()
# Out:
#       Week  Dengue_Count
# Year
# 2012    52            52
# 2013    52            52
# 2014    53            53
# 2015    53            53
# 2016    53            53
# 2017    53            53
# 2018    53            53
# 2019    47            47
# 2020    53            53
# 2021    52            52
# 2022    52            52
# 2023    53            53
# 2024    27            27

# %% [markdown]
# ### Data - Weather

# %% [markdown]
# Next, we clean and compile the __weather__ data. Most of the weather data has been scraped from NEA. Missing data was encoded as -1 in this dataset. As shown, the NEA dataset contains daily weather information information from multiple weather stations.

# %%
df_weather_NEA = df_weather_NEA_raw.copy()
df_weather_NEA.sample(5)
# Out:
#         Unnamed: 0               Station  Year  Month  Day  \
# 108533          21  Macritchie Reservoir  2022      8   22
# 159189          22       Boon Lay (East)  2014     12   23
# 218858           3         Marine Parade  2022      4    4
# 172533          11                 Simei  2016     10   12
# 61015            2           Buona Vista  2022     12    3
#
#         Daily Rainfall Total (mm)  Highest 30 min Rainfall (mm)  \
# 108533                        0.0                           0.0
# 159189                        0.0                           0.0
# 218858                        0.0                           0.0
# 172533                       -1.0                          -1.0
# 61015                        20.2                          17.0
#
#         Highest 60 min Rainfall (mm)  Highest 120 min Rainfall (mm)  \
# 108533                           0.0                            0.0
# 159189                           0.0                            0.0
# 218858                           0.0                            0.0
# 172533                          -1.0                           -1.0
# 61015                           18.4                           20.0
#
#         Mean Temperature (°C)  Maximum Temperature (°C)  \
# 108533                   -1.0                      -1.0
# 159189                   26.5                      29.1
# 218858                   -1.0                      -1.0
# 172533                   -1.0                      -1.0
# 61015                    -1.0                      -1.0
#
#         Minimum Temperature (°C)  Mean Wind Speed (km/h)  \
# 108533                      -1.0                    -1.0
# 159189                      24.9                     8.1
# 218858                      -1.0                    -1.0
# 172533                      -1.0                    -1.0
# 61015                       -1.0                    -1.0
#
#         Max Wind Speed (km/h)
# 108533                   -1.0
# 159189                   35.3
# 218858                   -1.0
# 172533                   -1.0
# 61015                    -1.0

# %% [markdown]
# Our dengue dataset above provides weekly dengue counts for the whole of Singapore. To match the dengue dataset, we take the mean values for the different weather conditions across different weather stations and over the week. Note that the highest rainfall columns consist of more than 100 missing values.

# %%
# Get week of year
df_weather_NEA = df_weather_NEA.replace(-1, np.nan)                                     # Encode missing values as NaN
df_weather_NEA.drop(columns=['Unnamed: 0'],inplace=True)                                # Drop index column
df_weather_NEA.dropna(subset=['Year','Month','Day'],inplace=True)                       # Dropping records where the date in missing
df_weather_NEA = df_weather_NEA.astype({'Year':'int','Month':'int','Day':'int'})        # Convert to date time and extract week of year
df_weather_NEA['date'] = pd.to_datetime(df_weather_NEA[['Year', 'Month', 'Day']])
df_weather_NEA['Week'] = df_weather_NEA['date'].dt.isocalendar().week
df_weather_NEA.drop(columns=['Day','date','Month','Station'],inplace=True)              # Drop obsolete columns

# Renaming columns for convenience.
df_weather_NEA.rename(columns={'Daily Rainfall Total (mm)':'Daily_Rainfall',
                               'Highest 30 min Rainfall (mm)':'Highest_30mm_Rain',
                               'Highest 60 min Rainfall (mm)':'Highest_60mm_Rain',
                               'Highest 120 min Rainfall (mm)':'Highest_120mm_Rain',
                               'Mean Temperature (°C)':'Mean_Temperature',
                               'Maximum Temperature (°C)':'Max_Temperature',
                               'Minimum Temperature (°C)':'Min_Temperature',
                               'Mean Wind Speed (km/h)':'Min_Wind_Speed',
                               'Max Wind Speed (km/h)':'Max_Wind_speed'},inplace=True)

# Taking mean values over all stations and over all days of a given week
df_weather_NEA = df_weather_NEA.groupby(['Year','Week']).mean()

# Check for missing values.
print(df_weather_NEA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 654 entries, (2012, 1) to (2024, 26)
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Daily_Rainfall      654 non-null    float64
#  1   Highest_30mm_Rain   550 non-null    float64
#  2   Highest_60mm_Rain   550 non-null    float64
#  3   Highest_120mm_Rain  550 non-null    float64
#  4   Mean_Temperature    654 non-null    float64
#  5   Max_Temperature     654 non-null    float64
#  6   Min_Temperature     654 non-null    float64
#  7   Min_Wind_Speed      654 non-null    float64
#  8   Max_Wind_speed      654 non-null    float64
# dtypes: float64(9)
# memory usage: 47.7 KB
# None

# %% [markdown]
# We drop highest 30mm, 60mm and 120mm rainfall columns for simplicity.

# %%
df_weather_NEA.drop(columns=[col for col in df_weather_NEA if ('Highest' in col)], inplace=True)
df_weather_NEA = df_weather_NEA.reset_index()

# %% [markdown]
# Humidity is well-known to be correlated with dengue fever but not provided by the NEA source. Therefore, we additionally look at relative humidity data from a separate dataset obtained from data.gov.sg.

# %%
# Get relative humidity dataframe
df_RH_datagov = df_weather_datagov_RH_raw.copy()
df_RH_datagov.sample(5)
# Out:
#        month  mean_rh
# 120  2022-01     77.4
# 71   2017-12     85.2
# 140  2023-09     73.6
# 14   2013-03     80.4
# 45   2015-10     75.4

# %% [markdown]
#  As shown, this dataset provides only monthly values. We assume that the relative humidity is constant over each month and fill in the missing values for each week accordingly.

# %%
# Fill in values for each week of year
df_RH_datagov['Year'] = pd.to_datetime(df_weather_datagov_RH_raw.month).dt.isocalendar().year           # Create year column
df_RH_datagov['Week'] = pd.to_datetime(df_weather_datagov_RH_raw.month).dt.isocalendar().week           # Create week column
df_RH_datagov.drop(columns=['month'],inplace=True)
df_RH_datagov.rename(columns={'mean_rh':'Relative_Humidity'},inplace=True)
df_weeks_temp = df_weather_NEA[['Year','Week']]                                                         # Get weeks of year over range of years considered
df_RH_datagov = df_RH_datagov.merge(df_weeks_temp,on=['Year','Week'],how='outer')
df_RH_datagov.ffill(inplace=True)                                                                       # Assume same humidity over all weeks of month

# %% [markdown]
# The relative humidity dataframe is merged into the weather dataframe to give the complete weather features required.

# %%
# Merge relative humidity data into other weather data
df_weather = df_weather_NEA.merge(df_RH_datagov,on=['Year','Week'],how='left')
df_weather.sample(5)
# Out:
#      Year  Week  Daily_Rainfall  Mean_Temperature  Max_Temperature  \
# 159  2015     4        2.903695         26.758647        30.668421
# 375  2019    10        1.300877         28.708257        33.345690
# 458  2020    41        6.429191         27.995238        31.103636
# 314  2018     1       12.879843         26.417647        29.662162
# 451  2020    34        8.800283         27.570536        31.031092
#
#      Min_Temperature  Min_Wind_Speed  Max_Wind_speed  Relative_Humidity
# 159        24.481203       11.889683       35.082540               77.6
# 375        26.093103        8.932800       30.692000               72.3
# 458        25.282727        8.642056       38.149123               75.4
# 314        24.361261        6.618110       26.839370               86.6
# 451        24.917647        8.108621       34.220325               76.8

# %% [markdown]
# ### Data - Google Trends

# %% [markdown]
# Next, __google search trends__ regarding dengue may indicate imminent occurence of dengue clusters. Specifically, we include search trends related to the keywords "dengue", "dengue+symptoms", "fever", and "mosquito".

# %%
# Renaming columns
df_trend_dengue = df_trend_dengue_raw.copy()
df_trend_dengue_symptoms = df_trend_dengue_symptoms_raw.copy()
df_trend_fever = df_trend_fever_raw.copy()
df_trend_mosquito = df_trend_mosquito_raw.copy()

df_trend_dengue.rename(columns={'dengue: (Singapore)':'Trend_Dengue'},inplace=True)
df_trend_dengue_symptoms.rename(columns={'dengue symptoms: (Singapore)':'Trend_Dengue_Symptoms'},inplace=True)
df_trend_fever.rename(columns={'fever: (Singapore)':'Trend_Fever'},inplace=True)
df_trend_mosquito.rename(columns={'mosquito: (Singapore)':'Trend_Mosquito'},inplace=True)

# Get week and year
df_trend_dengue['Year'] = pd.to_datetime(df_trend_dengue['Week']).dt.isocalendar().year
df_trend_dengue['Week'] = pd.to_datetime(df_trend_dengue['Week']).dt.isocalendar().week
df_trend_dengue_symptoms['Year'] = pd.to_datetime(df_trend_dengue_symptoms['Week']).dt.isocalendar().year
df_trend_dengue_symptoms['Week'] = pd.to_datetime(df_trend_dengue_symptoms['Week']).dt.isocalendar().week
df_trend_fever['Year'] = pd.to_datetime(df_trend_fever['Week']).dt.isocalendar().year
df_trend_fever['Week'] = pd.to_datetime(df_trend_fever['Week']).dt.isocalendar().week
df_trend_mosquito['Year'] = pd.to_datetime(df_trend_mosquito['Week']).dt.isocalendar().year
df_trend_mosquito['Week'] = pd.to_datetime(df_trend_mosquito['Week']).dt.isocalendar().week


# Combining into one dataframe
df_trends = df_trend_dengue.merge(df_trend_dengue_symptoms,how='left',on=['Week','Year'])
df_trends = df_trends.merge(df_trend_fever,how='left',on=['Week','Year'])
df_trends = df_trends.merge(df_trend_mosquito,how='left',on=['Week','Year'])
df_trends.drop_duplicates(subset=['Year','Week'],inplace=True) # Drop small number of repeated entries
df_trends
# Out:
#      Week  Trend_Dengue  Year  Trend_Dengue_Symptoms  Trend_Fever  \
# 0      52            51  2014                     58           72
# 8       1            51  2015                     74           71
# 9       2            51  2015                     66           74
# 10      3            49  2015                     60           69
# 11      4            62  2015                     62           70
# ..    ...           ...   ...                    ...          ...
# 800    24            63  2024                     59           82
# 801    25            63  2024                     77           78
# 802    26            58  2024                     76           85
# 803    27            57  2024                     73           94
# 804    28            57  2024                     77           90
#
#      Trend_Mosquito
# 0                58
# 8                71
# 9                59
# 10               59
# 11               68
# ..              ...
# 800              88
# 801              95
# 802              81
# 803              88
# 804              87
#
# [655 rows x 6 columns]

# %% [markdown]
# ### Data - Wolbachia and External Events

# %% [markdown]
# External, non-weather events may directly influence dengue incidence. In particular, __Project Wolbachia__ to curb dengue spread may have reduced dengue cases. Here, we consider Wolbachia efforts as the numerical feature `Wolbachia` given by the percentage of Singapore districts with Wolbachia release.

# %%
df_wolbachia = df_wolbachia_raw.drop(columns=['Wolbachia_Areas'])
df_wolbachia.sample(5)
# Out:
#      Year  Week  Wolbachia_Ratio
# 579  2022    52         0.272727
# 620  2023    41         0.272727
# 601  2023    22         0.272727
# 91   2013    40         0.000000
# 627  2023    48         0.272727

# %% [markdown]
# Additionally, __Covid-19 restrictions and increased construction activities__ after restrictions are lifted may have caused a rise in cases. The presence of such restrictions/activities are encoded as a categorical feature `External_Events` here.

# %%
df_external_events = df_wolbachia[['Year','Week']]
df_external_events['External_Events'] = 0
df_external_events.loc[(df_external_events.Year==2020) & (df_external_events.Week>=15) & (df_external_events.Week<=30),'External_Events'] = 1       # Period of high COVID restrictions, start of lockdown: 7th April 2020, end of phase 2: 17th July
df_external_events.loc[(df_external_events.Year==2022) & (df_external_events.Week>=10) & (df_external_events.Week<=40),'External_Events'] = 1       # Period of increased construction activity in 2022 between weeks 10 and 40

# %% [markdown]
# ### Compiled Dataset

# %% [markdown]
# We combined all data we have into a single dataframe. Visualizing all missing data below, we see that most of them are due to consideration of a 53rd week of the year. As mentioned earlier, some weeks in 2019 are also missing dengue fever counts.

# %%
df_raw = df_dengue.merge(df_weather,on=['Year','Week'],how='outer').merge(df_trends,on=['Year','Week'],how='outer')
df_raw = df_raw.merge(df_wolbachia,on=['Year','Week'],how='left')
df_raw = df_raw.merge(df_external_events,on=['Year','Week'],how='left')
display(df_raw[df_raw.isna().any(axis=1)])   # Show rows with missing values
# Out:
#      Year  Week  Dengue_Count  Daily_Rainfall  Mean_Temperature  \
# 0    2011    52           NaN             NaN               NaN
# 157  2014    53         158.0             NaN               NaN
# 263  2016    53           0.0        9.947647         26.211667
# 316  2017    53           0.0             NaN               NaN
# 369  2018    53           0.0             NaN               NaN
# 417  2019    48           NaN       13.375069         27.664486
# 418  2019    49           NaN        6.549143         27.418868
# 419  2019    50           NaN       27.321003         25.009091
# 420  2019    51           NaN        5.785920         26.448889
# 421  2019    52           NaN        2.205525         27.395050
# 527  2021    53           NaN       71.633600         23.847917
# 632  2023    53         274.0             NaN               NaN
# 659  2024    27         326.0             NaN               NaN
# 660  2024    28           NaN             NaN               NaN
#
#      Max_Temperature  Min_Temperature  Min_Wind_Speed  Max_Wind_speed  \
# 0                NaN              NaN             NaN             NaN
# 157              NaN              NaN             NaN             NaN
# 263        27.990000        24.400000        7.458333       34.603333
# 316              NaN              NaN             NaN             NaN
# 369              NaN              NaN             NaN             NaN
# 417        32.569027        25.070796        7.818033       33.086066
# 418        30.736036        25.310811       11.496610       39.640678
# 419        27.382692        23.375000        9.198214       32.920536
# 420        30.261458        24.387500        8.639167       30.013333
# 421        31.543925        25.035514       10.892683       33.669106
# 527        25.500000        22.296078        8.640000       34.633333
# 632              NaN              NaN             NaN             NaN
# 659              NaN              NaN             NaN             NaN
# 660              NaN              NaN             NaN             NaN
#
#      Relative_Humidity  Trend_Dengue  Trend_Dengue_Symptoms  Trend_Fever  \
# 0                  NaN          64.0                   72.0         87.0
# 157                NaN           NaN                    NaN          NaN
# 263               84.8           NaN                    NaN          NaN
# 316                NaN           NaN                    NaN          NaN
# 369                NaN           NaN                    NaN          NaN
# 417               83.9          40.0                   39.0         76.0
# 418               83.9          40.0                   40.0         76.0
# 419               83.9          39.0                   35.0         88.0
# 420               83.9          43.0                   57.0         95.0
# 421               83.9          22.0                   28.0         56.0
# 527               77.4           NaN                    NaN          NaN
# 632                NaN           NaN                    NaN          NaN
# 659                NaN          57.0                   73.0         94.0
# 660                NaN          57.0                   77.0         90.0
#
#      Trend_Mosquito  Wolbachia_Ratio  External_Events
# 0              68.0              NaN              NaN
# 157             NaN         0.000000              0.0
# 263             NaN         0.036364              0.0
# 316             NaN         0.036364              0.0
# 369             NaN         0.036364              0.0
# 417            72.0         0.036364              0.0
# 418            67.0         0.036364              0.0
# 419            70.0         0.036364              0.0
# 420            68.0         0.036364              0.0
# 421            64.0         0.036364              0.0
# 527             NaN         0.090909              0.0
# 632             NaN         0.272727              0.0
# 659            88.0              NaN              NaN
# 660            87.0              NaN              NaN

# %% [markdown]
# Here, we:
# 1. drop 53rd week from each year
# 2. fill the missing values with `.ffill` methods.

# %%
# Final touches
def year_week_to_date(row):
    # Convert year and week to datetime format
    year = str(row["Year"])[:-2]
    week = str(row["Week"])[:-2]
    date = f"{year}-{week}-1"
    dt = datetime.strptime(date, "%Y-%W-%w")
    return dt

df_raw = df_raw.loc[df_raw['Week']!=53]                           # Drop all week 53s
df_raw.ffill(inplace=True)                                        # Fill missing values
df_raw.dropna(inplace=True)                                       # Remove straggling row with missing values
df_raw = df_raw.astype({'Week':'int','Year':'int'})               # Ensure clean datatypes
df_raw['Date'] = df_raw.apply(lambda row: year_week_to_date(row),axis=1) # Use datetime indexing on compiled dataframe
df_raw.set_index('Date',inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# The compiled dataset used consists of weather conditions, google search trends, as well as indicators for Wolbachia and any external events.

# %%
# Create copy of main dataframe and show structure
df_plot = df_raw.copy()
df_plot.sample(5)
# Out:
#             Year  Week  Dengue_Count  Daily_Rainfall  Mean_Temperature  \
# Date
# 2017-10-16  2017    42          63.0        0.394545         29.612605
# 2023-02-20  2023     8         147.0        0.866254         27.290517
# 2020-10-05  2020    40         603.0        6.535920         27.759048
# 2020-05-18  2020    20         525.0        8.103582         29.208571
# 2012-04-23  2012    17          64.0        3.582324         28.555303
#
#             Max_Temperature  Min_Temperature  Min_Wind_Speed  Max_Wind_speed  \
# Date
# 2017-10-16        33.055556        26.840476        7.191729       29.878195
# 2023-02-20        31.267241        25.008621       11.887805       37.631707
# 2020-10-05        31.041964        25.091071        8.145455       32.855085
# 2020-05-18        32.671429        26.305357        8.871171       35.650847
# 2012-04-23        32.208571        25.715714        6.610714       30.906429
#
#             Relative_Humidity  Trend_Dengue  Trend_Dengue_Symptoms  \
# Date
# 2017-10-16               82.5          79.0                   58.0
# 2023-02-20               79.4          45.0                   53.0
# 2020-10-05               75.4          25.0                   30.0
# 2020-05-18               79.1          31.0                   37.0
# 2012-04-23               85.1          63.0                    0.0
#
#             Trend_Fever  Trend_Mosquito  Wolbachia_Ratio  External_Events
# Date
# 2017-10-16         66.0            84.0         0.036364              0.0
# 2023-02-20         70.0            75.0         0.272727              0.0
# 2020-10-05         30.0            47.0         0.090909              0.0
# 2020-05-18         32.0            61.0         0.090909              1.0
# 2012-04-23         84.0            91.0         0.000000              0.0

# %% [markdown]
# As shown below, there are no missing values in the dataset.

# %%
# Show dataset datatypes and check for missing values
df_plot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 652 entries, 2012-01-02 to 2024-07-08
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   652 non-null    int64
#  1   Week                   652 non-null    int64
#  2   Dengue_Count           652 non-null    float64
#  3   Daily_Rainfall         652 non-null    float64
#  4   Mean_Temperature       652 non-null    float64
#  5   Max_Temperature        652 non-null    float64
#  6   Min_Temperature        652 non-null    float64
#  7   Min_Wind_Speed         652 non-null    float64
#  8   Max_Wind_speed         652 non-null    float64
#  9   Relative_Humidity      652 non-null    float64
#  10  Trend_Dengue           652 non-null    float64
#  11  Trend_Dengue_Symptoms  652 non-null    float64
#  12  Trend_Fever            652 non-null    float64
#  13  Trend_Mosquito         652 non-null    float64
#  14  Wolbachia_Ratio        652 non-null    float64
#  15  External_Events        652 non-null    float64
# dtypes: float64(14), int64(2)
# memory usage: 86.6 KB

# %% [markdown]
# First, we look into the trends of dengue fever over the years. As shown, most years show a peak in the middle of the year, with years 2019, 2020 and 2022 showing higher than usual dengue fever cases, possibly related to Covid related lockdown. Year 2023 again shows lower dengue fever cases as lockdown restrictions are lifted.

# %%
# Create the line plot
fig, ax = plt.subplots(1,1,figsize=(10,5))
key_years = [2019,2020,2021,2022,2023,2024]
df_plot['Years'] = df_plot['Year'].apply(lambda x: str(x) if x in key_years else '2012-2018')
palette = {'2012-2018': 'gray', '2019': 'red', '2020':'blue','2021':'green','2022':'cyan','2023':'purple','2024':'black'}
sns.lineplot(data=df_plot, x='Week', y='Dengue_Count', hue='Years', palette=palette, legend=True,ax=ax)
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = [2.5,6.5,11,15.5,20,24.5,28.5,33,37.5,42,46.5,50.5]
ax.set_xticks(month_ticks)
ax.set_xticklabels(month_labels)
ax.set_xlabel('Month')
ax.set_ylabel('Dengue Count')
ax.set_title('Dengue Count (2012-2024)');

# %% [markdown]
# Using a heatmap of linear correlation, we look at the relationship between dengue cases and the different temperature conditions. We see some correlation with temperature and relative humidity. However, linear relationships may not fully capture the complexity of dengue incidence in response to weather changes. In particular, dengue cases may be related to past weather conditions, as an Aedes egg can take 7 to 10 days to hatch and develop into an adult mosquito. Such relationships can be more properly explored in via statistical modelling.

# %%
sns.heatmap(df_plot[['Dengue_Count','Daily_Rainfall', 'Mean_Temperature',
       'Max_Temperature', 'Min_Temperature', 'Min_Wind_Speed',
       'Max_Wind_speed','Relative_Humidity']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Finally, we see if there is a relationship between google search trends on Dengue and incidence of Dengue fever. As shown, there is a strong correlation between search for Dengue symptoms and Dengue fever incidence.

# %%
sns.heatmap(df_plot[['Dengue_Count','Trend_Dengue', 'Trend_Dengue_Symptoms','Trend_Fever','Trend_Mosquito']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Finally, we look at the effect of external events with similar plot, showing a strong correlation with external events.

# %%
sns.heatmap(df_plot[['Dengue_Count','Wolbachia_Ratio', 'External_Events']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Forecast Models

# %% [markdown]
# We investigate three forecasting models to predict future occurrences of dengue fever. Here, we evaluate each model's performance on two forecast windows: for a short-term prediction (8 weeks) and for a long-term prediction (24 weeks), using the Mean Absolute Error (MAE) metric.
#
# To evaluate the performance of the models below, we use a cross-validation approach appropriate for time series data, known as a time series split using `sklearn.model_selection.TimeSeriesSplit`. Here we forecast for a window of 8 weeks. The difference between this approach and the usual K-fold cross-validation approach is illustrated by [Assaad and Fayek, 2012](https://www.researchgate.net/publication/355889701_Predicting_the_Price_of_Crude_Oil_and_its_Fluctuations_Using_Computational_Econometrics_Deep_Learning_LSTM_and_Convolutional_Neural_Networks) and reproduced below.
#
# ![K-fold Cross Validation vs Time Series Split](assets/timeseriessplit.png)
#
# In the following sections, we will create the `tscv` object which will perform the required splits and return an iterator of the train and test indices required. In the time series splits performed herein, we configure `n_splits` and `test_size` such that the smallest training set contains at least approximately 2 years' worth of datapoints for training. An example of the process is shown below for an 8 week forecast window.

# %%
# Split into train and test sets
forecast_window = 8
tscv = TimeSeriesSplit(n_splits=68, test_size=forecast_window)

# %% [markdown]
# ### ARIMA/SARIMAX

# %% [markdown]
# First, we start with the classical family of time-series models i.e. ARIMA/SARIMA/SARIMAX.

# %%
df_ts = df_raw.copy()
df_ts
# Out:
#             Year  Week  Dengue_Count  Daily_Rainfall  Mean_Temperature  \
# Date
# 2012-01-02  2012     1          74.0       10.266250         26.866026
# 2012-01-09  2012     2          66.0        3.740000         26.434783
# 2012-01-16  2012     3          61.0       13.200000         27.238235
# 2012-01-23  2012     4          52.0        1.522381         26.784672
# 2012-01-30  2012     5          85.0        7.472143         26.544286
# ...          ...   ...           ...             ...               ...
# 2024-06-10  2024    24         302.0        8.764846         28.844828
# 2024-06-17  2024    25         296.0       12.723232         28.141880
# 2024-06-24  2024    26         290.0        9.580731         28.566387
# 2024-07-01  2024    27         326.0        9.580731         28.566387
# 2024-07-08  2024    28         326.0        9.580731         28.566387
#
#             Max_Temperature  Min_Temperature  Min_Wind_Speed  Max_Wind_speed  \
# Date
# 2012-01-02        30.521875        24.589375       10.653125       36.228750
# 2012-01-09        29.797143        23.925714        8.486429       33.596429
# 2012-01-16        31.835000        24.474286        6.683571       29.836429
# 2012-01-23        30.781429        24.417857        9.255714       33.138571
# 2012-01-30        30.213571        24.176429        9.028571       33.248571
# ...                     ...              ...             ...             ...
# 2024-06-10        32.706897        25.794828        5.838235       29.777451
# 2024-06-17        31.214530        25.094872        7.950485       38.554369
# 2024-06-24        32.085714        25.927731        6.776190       31.419048
# 2024-07-01        32.085714        25.927731        6.776190       31.419048
# 2024-07-08        32.085714        25.927731        6.776190       31.419048
#
#             Relative_Humidity  Trend_Dengue  Trend_Dengue_Symptoms  \
# Date
# 2012-01-02               87.3          50.0                    0.0
# 2012-01-09               87.3          50.0                   83.0
# 2012-01-16               87.3          51.0                   58.0
# 2012-01-23               87.3          60.0                    0.0
# 2012-01-30               85.6          55.0                   43.0
# ...                       ...           ...                    ...
# 2024-06-10               76.6          63.0                   59.0
# 2024-06-17               76.6          63.0                   77.0
# 2024-06-24               76.6          58.0                   76.0
# 2024-07-01               76.6          57.0                   73.0
# 2024-07-08               76.6          57.0                   77.0
#
#             Trend_Fever  Trend_Mosquito  Wolbachia_Ratio  External_Events
# Date
# 2012-01-02         85.0            64.0         0.000000              0.0
# 2012-01-09         79.0            61.0         0.000000              0.0
# 2012-01-16         84.0            75.0         0.000000              0.0
# 2012-01-23         78.0            83.0         0.000000              0.0
# 2012-01-30         77.0            86.0         0.000000              0.0
# ...                 ...             ...              ...              ...
# 2024-06-10         82.0            88.0         0.272727              0.0
# 2024-06-17         78.0            95.0         0.272727              0.0
# 2024-06-24         85.0            81.0         0.272727              0.0
# 2024-07-01         94.0            88.0         0.272727              0.0
# 2024-07-08         90.0            87.0         0.272727              0.0
#
# [652 rows x 16 columns]

# %%
df_ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 652 entries, 2012-01-02 to 2024-07-08
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   652 non-null    int64
#  1   Week                   652 non-null    int64
#  2   Dengue_Count           652 non-null    float64
#  3   Daily_Rainfall         652 non-null    float64
#  4   Mean_Temperature       652 non-null    float64
#  5   Max_Temperature        652 non-null    float64
#  6   Min_Temperature        652 non-null    float64
#  7   Min_Wind_Speed         652 non-null    float64
#  8   Max_Wind_speed         652 non-null    float64
#  9   Relative_Humidity      652 non-null    float64
#  10  Trend_Dengue           652 non-null    float64
#  11  Trend_Dengue_Symptoms  652 non-null    float64
#  12  Trend_Fever            652 non-null    float64
#  13  Trend_Mosquito         652 non-null    float64
#  14  Wolbachia_Ratio        652 non-null    float64
#  15  External_Events        652 non-null    float64
# dtypes: float64(14), int64(2)
# memory usage: 86.6 KB

# %% [markdown]
# To use any of classical time-series models, the first step is to identify if the dataset is **stationary** i.e. the mean and variance of the target value (in this case, dengue cases) remains relatively the same over time.

# %% [markdown]
# We typically check stationarity with:
# 1. Rolling Statistics Plots
# 2. ADF and KPSS tests

# %%
# Calculating mean and std dev for Dengue count
rolling_mean = df_ts['Dengue_Count'].rolling(window=12).mean() # rolling window of 12 months
rolling_std = df_ts['Dengue_Count'].rolling(window=12).std()

# Plot rolling statistics
plt.figure(figsize=(15, 7))
plt.plot(df_ts.index, df_ts['Dengue_Count'], label='Original')
plt.plot(df_ts.index, rolling_mean, label='Rolling Mean', color='red')
plt.plot(df_ts.index, rolling_std, label='Rolling Std', color='black')
plt.title('Rolling Mean & Standard Deviation')
plt.xlabel('Date')
plt.ylabel('Dengue Count')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The plots are actually a bit inconclusive with both the mean and std deviation trends showing very slight changes over time.
#
# Moving onto the stationarity tests - both rely on null and alternative hypotheses
#
# a. ADF test - the null hypothesis is that the dataset is non-stationary
#
# b. KPSS test - the null hypothesis is the dataset is stationary

# %%
# Augmented Dickey-Fuller test
adf_result = adfuller(df_ts['Dengue_Count'])
print('Augmented Dickey-Fuller results:')
print(f'ADF Statistic: {adf_result[0]:.3f}')
print(f'p-value: {adf_result[1]:.3f}')

# Kwiatkowski-Phillips-Schmidt-Shin test
kpss_stat, kpss_p_value, kpss_lags, kpss_crit = kpss(df_ts['Dengue_Count'], regression='c', nlags="auto")
kpss_result = {
    'KPSS Statistic': kpss_stat,
    'p-value': round(kpss_p_value, 3),
    'Lags Used': kpss_lags,
    'Critical Values': kpss_crit
}
print('KPSS test results:')
for key, value in kpss_result.items():
    print(f'{key}: {value}')
# Out:
# Augmented Dickey-Fuller results:
# ADF Statistic: -3.983
# p-value: 0.002
# KPSS test results:
# KPSS Statistic: 0.2371534071544654
# p-value: 0.1
# Lags Used: 16
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}

# %% [markdown]
# The ADF test returns a p-value of 0.001, which is less than 0.05. The alternate hypothesis is confirmed - the dataset is stationary.
# The KPSS test returns a p-value of 0.1, which is more 0.05. The null hypothesis is confirmed - the dataset is stationary

# %% [markdown]
# Now, as we can apply the classical time-series models - we have three choices:
#
# 1. ARIMA - using only the dengue counts with auto-regression and moving averages
#
# 2. SARIMA - same as above, but with additional seasonality parameters
#
# 3. SARIMAX - same as SARIMA, but with additional external factors.

# %% [markdown]
# From our analysis and EDA, we've seen some correlation between the dengue cases and external factors such as humidity, rainfall, and even Google trend data.
#
# So, we'll jump straight to the 3rd model - SARIMAX, considering all features besides datetime, and the target as the dengue count

# %% [markdown]
# SARIMAX has a number of hyperparameters to identify and set. These are detailed below:

# %% [markdown]
# **Non-seasonality parameters:**
#
#  _p_ (this is the lookback window)
#
# _d_ = 0 (we set this at zero, as the dataset is stationary)
#
#  _q_ (residuals, error rate)

# %% [markdown]
# **Seasonality parameters:**
#
# _s_ = 52 (for data spanning years, this is an acceptable value. 52 weeks = 1 year)
#
# _P_ (look back period by season)
#
# _D_ = 1 (differencing by the previous season's value, to eliminate seasonal trends)
#
# _Q_ (residual / error rate from previous season)

# %% [markdown]
# ACF and PACF plots are used to identify the p,q and P,Q parameters.

# %%
# ACF and PACF for non-seasonal p,q
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))

plot_acf(df_ts['Dengue_Count'], lags=50, ax=ax1)
ax1.set_title('Autocorrelation Function (ACF)')

plot_pacf(df_ts['Dengue_Count'], lags=50, ax=ax2)
ax2.set_title('Partial Autocorrelation Function (PACF)')

plt.tight_layout()
plt.show()

# %% [markdown]
# p-values are determined from the PACF graph - after 1, there's a sharp drop. So, we'll set p = 1
# q-values are ascertained from the ACF graph - after 1, the graph curves downward gently. So, we'll set q = 1

# %%
# Seasonal differencing to plot seasonal ACF and PACF
seasonal_diff = df_ts['Dengue_Count'].diff(52).dropna()

# Plot ACF and PACF for seasonal differencing
fig, (ax3, ax4) = plt.subplots(2, 1, figsize=(15, 10))

plot_acf(seasonal_diff, lags=50, ax=ax3)
ax3.set_title('Seasonal Autocorrelation Function (ACF)')

plot_pacf(seasonal_diff, lags=50, ax=ax4)
ax4.set_title('Seasonal Partial Autocorrelation Function (PACF)')

plt.tight_layout()
plt.show()

# %% [markdown]
# The seasonal plots follow a similar pattern as the non-seasonal ones.
# Therefore, we choose P = 1 (from the PACF) and Q = 1 from the ACF graph.

# %% [markdown]
# This completes all the parameters we need. Moving onto SARIMAX modeling, we first consider a short forecast window of 8 weeks.

# %%
# Feature and target definition
features = ['Daily_Rainfall', 'Mean_Temperature', 'Relative_Humidity',
                   'Max_Temperature', 'Min_Temperature', 'Min_Wind_Speed',
                   'Max_Wind_speed', 'Trend_Dengue', 'Trend_Dengue_Symptoms',
                   'Trend_Fever', 'Trend_Mosquito','Wolbachia_Ratio','External_Events']
target = df_ts['Dengue_Count']

# %%
# Parameters for SARIMAX
order = (1, 0, 1)                       # written as p, d, q
seasonal_order = (1, 1, 1, 52)          # written as P, D, Q, s

# Initialize a list to store all predictions
df_preds_sar_8 = pd.Series(index=target.index, dtype=float)

# Split into train and test sets for an 8 week prediction
forecast_window = 8
tscv = TimeSeriesSplit(n_splits=68, test_size=forecast_window)

# Time series cross-validation with tqdm progress bar
for train_index, test_index in tqdm(tscv.split(df_ts), total=tscv.get_n_splits(), desc="Cross-Validation"):
    train_features, test_features = df_ts[features].iloc[train_index], df_ts[features].iloc[test_index]
    train_target, test_target = target.iloc[train_index], target.iloc[test_index]

    # Scale the features
    scaler = StandardScaler()
    train_features_scaled = scaler.fit_transform(train_features)
    test_features_scaled = scaler.transform(test_features)

    try:                                                         # try-except block to catch errors
        # Fit SARIMAX model
        model = SARIMAX(train_target, exog=train_features_scaled, order=order, seasonal_order=seasonal_order)
        results = model.fit(disp=False)

        # Make predictions
        predictions = results.predict(start=test_index[0], end=test_index[-1], exog=test_features_scaled)

        # Store predictions
        df_preds_sar_8[test_index] = predictions

    except np.linalg.LinAlgError as e:
        print(f'Error for split {len(df_preds_sar_8.dropna())}: {e}')
        continue
# Out:
# Cross-Validation: 100%|██████████| 68/68 [50:14<00:00, 44.32s/it]

# %%
# Calculate and print average RMSE
df_testset_pred_obs = pd.concat([df_preds_sar_8,target],axis=1).dropna()
mae_sar_8 = mean_absolute_error(df_testset_pred_obs.iloc[:,0],df_testset_pred_obs.iloc[:,1])
print(f'Test MAE: {mae_sar_8:.3f}')
# Out:
# Test MAE: 99.989

# %%
# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(target,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_sar_8,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_sar_8.index[108], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'SARIMAX Dengue Count Prediction, Forecast Window = 8 weeks, MAE = {mae_sar_8:.3f}');

# %% [markdown]
# From the above plot, we can see that the predicted cases (in red) is lagging slightly.
# The MAE is a more tangible indicator at 99.99 - or rather, the overall error for each week will be around based on this model will be ~100 cases.
#
# Next, we consider a larger forecast windows of 24 weeks (6 months).

# %%
# Parameters for SARIMAX
order = (1, 0, 1)                       # written as p, d, q
seasonal_order = (1, 1, 1, 52)          # written as P, D, Q, s

# Initialize a list to store all predictions
df_preds_sar_24 = pd.Series(index=target.index, dtype=float)

# Split into train and test sets for a 24 week prediction
forecast_window = 24
tscv = TimeSeriesSplit(n_splits=23, test_size=forecast_window)

# Time series cross-validation with tqdm progress bar
for train_index, test_index in tqdm(tscv.split(df_ts), total=tscv.get_n_splits(), desc="Cross-Validation"):
    train_features, test_features = df_ts[features].iloc[train_index], df_ts[features].iloc[test_index]
    train_target, test_target = target.iloc[train_index], target.iloc[test_index]

    # Scale the features
    scaler = StandardScaler()
    train_features_scaled = scaler.fit_transform(train_features)
    test_features_scaled = scaler.transform(test_features)

    try:                                                         # try-except block to catch errors
        # Fit SARIMAX model
        model = SARIMAX(train_target, exog=train_features_scaled, order=order, seasonal_order=seasonal_order)
        results = model.fit(disp=False)

        # Make predictions
        predictions = results.predict(start=test_index[0], end=test_index[-1], exog=test_features_scaled)

        # Store predictions
        df_preds_sar_24[test_index] = predictions

    except np.linalg.LinAlgError as e:
        print(f'Error for split {len(df_preds_sar_24.dropna())}: {e}')
        continue
# Out:
# Cross-Validation: 100%|██████████| 23/23 [16:40<00:00, 43.50s/it]

# %%
# Calculate and print average RMSE
df_testset_pred_obs = pd.concat([df_preds_sar_24,target],axis=1).dropna()
rmse_sar_24 = np.sqrt(mean_squared_error(df_testset_pred_obs.iloc[:,0],df_testset_pred_obs.iloc[:,1]))
mae_sar_24 = mean_absolute_error(df_testset_pred_obs.iloc[:,0],df_testset_pred_obs.iloc[:,1])
print(f'Test MAE: {mae_sar_24:.3f}')
# Out:
# Test MAE: 169.672

# %%
# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(target,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_sar_24,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_sar_24.index[100], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'SARIMAX Dengue Count Prediction, Forecast Window = 24 weeks, MAE = {mae_sar_24:.3f}');

# %% [markdown]
# For a forecast window of 24 week, the prediction accuracy has deteriorated as expected, with an MAE of 170. It is noted that model training for SARIMAX took a significant amount of time. Other models may be more appropriate if frequent retraining and speed of deployment is crucial.

# %% [markdown]
# ### Pre- and Post-processing for Tabular Techniques

# %% [markdown]
# Unlike time series modelling methods like ARIMA, techniques like linear regression and XGBoost do not naturally account for past values in the sequence. Further processing is required to create lagged values of the features and/or targets as additional input features to the model. We consider using 5 weeks' worth of past data to predict the dengue counts over the next 8 weeks.

# %%
# Create dataframe with lagged values for tabular approach
df_tab = df_raw.copy()
target_lags = range(1, 6)                                         # Lagged values to use for target, i.e. dengue count
feature_lags = range(1, 6)                                        # Lagged values to use for features
lagged_features = ['Daily_Rainfall', 'Mean_Temperature', 'Relative_Humidity',
                   'Max_Temperature', 'Min_Temperature', 'Min_Wind_Speed',
                   'Max_Wind_speed', 'Trend_Dengue', 'Trend_Dengue_Symptoms',
                   'Trend_Fever', 'Trend_Mosquito','Wolbachia_Ratio','External_Events']

# Add feature lags
for feat in lagged_features:
    for lag in feature_lags:
        df_tab[f'{feat}_Lag_{lag}'] = df_tab[feat].shift(lag)
        
# Add target lags
dict_target_lags = {}                                             # Keep track of lagged target names
for lag in target_lags:
    dict_target_lags[lag] = f'Dengue_Count_Lag_{lag}'
    df_tab[dict_target_lags[lag]] = df_tab['Dengue_Count'].shift(lag)    

df_tab.head(10)
# Out:
#             Year  Week  Dengue_Count  Daily_Rainfall  Mean_Temperature  \
# Date
# 2012-01-02  2012     1          74.0       10.266250         26.866026
# 2012-01-09  2012     2          66.0        3.740000         26.434783
# 2012-01-16  2012     3          61.0       13.200000         27.238235
# 2012-01-23  2012     4          52.0        1.522381         26.784672
# 2012-01-30  2012     5          85.0        7.472143         26.544286
# 2012-02-06  2012     6          87.0        1.014048         27.506569
# 2012-02-13  2012     7          65.0        4.861905         26.859712
# 2012-02-20  2012     8          51.0        5.050476         27.614388
# 2012-02-27  2012     9          55.0        6.045714         27.161481
# 2012-03-05  2012    10          46.0       10.392381         27.139098
#
#             Max_Temperature  Min_Temperature  Min_Wind_Speed  Max_Wind_speed  \
# Date
# 2012-01-02        30.521875        24.589375       10.653125       36.228750
# 2012-01-09        29.797143        23.925714        8.486429       33.596429
# 2012-01-16        31.835000        24.474286        6.683571       29.836429
# 2012-01-23        30.781429        24.417857        9.255714       33.138571
# 2012-01-30        30.213571        24.176429        9.028571       33.248571
# 2012-02-06        32.057143        24.721429        9.998571       32.852857
# 2012-02-13        31.096429        24.369286        7.521429       33.143571
# 2012-02-20        31.600000        25.264286        8.017143       29.712857
# 2012-02-27        31.421429        24.715714        6.747143       31.630714
# 2012-03-05        30.724286        24.247857        6.557143       34.064286
#
#             Relative_Humidity  ...  External_Events_Lag_1  \
# Date                           ...
# 2012-01-02               87.3  ...                    NaN
# 2012-01-09               87.3  ...                    0.0
# 2012-01-16               87.3  ...                    0.0
# 2012-01-23               87.3  ...                    0.0
# 2012-01-30               85.6  ...                    0.0
# 2012-02-06               85.6  ...                    0.0
# 2012-02-13               85.6  ...                    0.0
# 2012-02-20               85.6  ...                    0.0
# 2012-02-27               87.3  ...                    0.0
# 2012-03-05               87.3  ...                    0.0
#
#             External_Events_Lag_2  External_Events_Lag_3  \
# Date
# 2012-01-02                    NaN                    NaN
# 2012-01-09                    NaN                    NaN
# 2012-01-16                    0.0                    NaN
# 2012-01-23                    0.0                    0.0
# 2012-01-30                    0.0                    0.0
# 2012-02-06                    0.0                    0.0
# 2012-02-13                    0.0                    0.0
# 2012-02-20                    0.0                    0.0
# 2012-02-27                    0.0                    0.0
# 2012-03-05                    0.0                    0.0
#
#             External_Events_Lag_4  External_Events_Lag_5  Dengue_Count_Lag_1  \
# Date
# 2012-01-02                    NaN                    NaN                 NaN
# 2012-01-09                    NaN                    NaN                74.0
# 2012-01-16                    NaN                    NaN                66.0
# 2012-01-23                    NaN                    NaN                61.0
# 2012-01-30                    0.0                    NaN                52.0
# 2012-02-06                    0.0                    0.0                85.0
# 2012-02-13                    0.0                    0.0                87.0
# 2012-02-20                    0.0                    0.0                65.0
# 2012-02-27                    0.0                    0.0                51.0
# 2012-03-05                    0.0                    0.0                55.0
#
#             Dengue_Count_Lag_2  Dengue_Count_Lag_3  Dengue_Count_Lag_4  \
# Date
# 2012-01-02                 NaN                 NaN                 NaN
# 2012-01-09                 NaN                 NaN                 NaN
# 2012-01-16                74.0                 NaN                 NaN
# 2012-01-23                66.0                74.0                 NaN
# 2012-01-30                61.0                66.0                74.0
# 2012-02-06                52.0                61.0                66.0
# 2012-02-13                85.0                52.0                61.0
# 2012-02-20                87.0                85.0                52.0
# 2012-02-27                65.0                87.0                85.0
# 2012-03-05                51.0                65.0                87.0
#
#             Dengue_Count_Lag_5
# Date
# 2012-01-02                 NaN
# 2012-01-09                 NaN
# 2012-01-16                 NaN
# 2012-01-23                 NaN
# 2012-01-30                 NaN
# 2012-02-06                74.0
# 2012-02-13                66.0
# 2012-02-20                61.0
# 2012-02-27                52.0
# 2012-03-05                85.0
#
# [10 rows x 86 columns]

# %% [markdown]
# Prediction using the trained model is similarly not straightforward, as compared to models like ARIMA. For example, when forecasting the target value 8 weeks in the future, we may need to use target values from weeks 3,4,5,6,7 as lagged values. Unfortunately, these values are not known a priori. For a proper model evaluation, we have to use predicted rather than known values for weeks 3,4,5,6,7 as lagged values, entailing a sequential prediction approach. The `get_sequential_predictions` function below perform such a sequential prediction.

# %%
def get_sequential_predictions(model, X,
                               dict_target_lags: Dict[int, str]):
    '''
    Get predictions using newly predicted labels as lagged labels.
    model: Model with predict method
    X: Features
    dict_target_lags: Dictionary with key as lagged target number, and value as column name of target label.
    '''

    X_pred = X.copy()

    target_lags = list(dict_target_lags.keys())                                                 # Lagged target names
    lag_target_col_names = list(dict_target_lags.values())                                      # Lag values for target
    
    lag_target_col_locs = [X_pred.columns.get_loc(col) for col in lag_target_col_names]         # Integer index locations (use with iloc) of lagged target

    pred_val = np.zeros(X_pred.shape[0])                                                        # Initialize predicted value array

    for i in range(X_pred.shape[0]):
        pred_val[i] = model.predict(X_pred.iloc[i:i+1,:])                                       # Predict current value, keep input in required dataframe format
        for k,j in enumerate(target_lags):                                                      # Add predicted value to X_val as lagged target for subsequent rows
            try:
                X_pred.iloc[i+j,lag_target_col_locs[k]] = pred_val[i]
            except:
                continue
            
    pred_val = np.round(pred_val)                                                               # Round numbers to integers
    pred_val = np.clip(pred_val, 0, 10000000)                                                   # Clip numbers to keep positive and prevent extreme values
    
    return pred_val

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# Another framework we will be using is Sci-Kit Learn's Linear Regression. For Linear Regression, we cannot feed NaN values into the model. Hence the first 5 rows containing NaN values, due to the 5-week lagged features added, will be dropped to fit the model. As before, we first consider a short forecast window of 8 weeks.

# %%
# Copying a new dataframe and dropping the first 5 rows
df_lr = df_tab.copy()
df_lr = df_lr.drop(df_lr.index[:5])

# Create feature and target dataframes
df_features_lr = df_lr.copy()[[col for col in df_tab.columns if not (col in ['Year','Dengue_Count'])]]
df_target_lr = df_lr.copy()[['Dengue_Count']]

# Split into train and test sets for an 8 week prediction
forecast_window = 8
tscv = TimeSeriesSplit(n_splits=68, test_size=forecast_window)

# Collect predictions
preds = []
for i, (train_ind,test_ind) in enumerate(tscv.split(df_features_lr)):
    
    # Initialize LinearRegression() model
    model = LinearRegression()

    # Define train & test data
    X_train_set = df_features_lr.iloc[train_ind,:]
    y_train_set = df_target_lr.iloc[train_ind]
    X_test_set = df_features_lr.iloc[test_ind,:]
    y_test_set = df_target_lr.iloc[test_ind]

    # Train the model
    model.fit(X_train_set, y_train_set)

    # Get predictions
    y_pred = get_sequential_predictions(model, X_test_set,
                                    dict_target_lags=dict_target_lags)
    
    y_pred = pd.DataFrame(y_pred,columns=['Dengue_Count'],index=X_test_set.index)
    preds.append(y_pred)


df_preds_lr_8 = pd.concat(preds)
mae_lr_8 = mean_absolute_error(df_target_lr.loc[df_preds_lr_8.index],df_preds_lr_8)

# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(df_target_lr,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_lr_8,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_lr_8.index[0], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'Linear Regression Dengue Count Prediction, Forecast Window = 8 weeks, MAE = {mae_lr_8:.1f}');

# %% [markdown]
# An MAE of 97 is obtained. Next, we consider a large forecast window of 24 weeks (6 months).

# %%
# Copying a new dataframe and dropping the first 5 rows
df_lr = df_tab.copy()
df_lr = df_lr.drop(df_lr.index[:5])

# Create feature and target dataframes
df_features_lr = df_lr.copy()[[col for col in df_tab.columns if not (col in ['Year','Dengue_Count'])]]
df_target_lr = df_lr.copy()[['Dengue_Count']]

# Split into train and test sets for a 24 week prediction
forecast_window =24
tscv = TimeSeriesSplit(n_splits=23, test_size=forecast_window)

# Collect predictions
preds = []
for i, (train_ind,test_ind) in enumerate(tscv.split(df_features_lr)):
    
    # Initialize LinearRegression() model
    model = LinearRegression()

    # Define train & test data
    X_train_set = df_features_lr.iloc[train_ind,:]
    y_train_set = df_target_lr.iloc[train_ind]
    X_test_set = df_features_lr.iloc[test_ind,:]
    y_test_set = df_target_lr.iloc[test_ind]

    # Train the model
    model.fit(X_train_set, y_train_set)

    # Get predictions
    y_pred = get_sequential_predictions(model, X_test_set,
                                    dict_target_lags=dict_target_lags)
    
    y_pred = pd.DataFrame(y_pred,columns=['Dengue_Count'],index=X_test_set.index)
    preds.append(y_pred)


df_preds_lr_24 = pd.concat(preds)
mae_lr_24 = mean_absolute_error(df_target_lr.loc[df_preds_lr_24.index],df_preds_lr_24)

# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(df_target_lr,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_lr_24,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_lr_24.index[0], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'Linear Regression Dengue Count Prediction, Forecast Window = 24 weeks, MAE = {mae_lr_24:.1f}');

# %% [markdown]
# A larger forecast window at 24 weeks gives an MAE of 148 for the linear regression model.

# %% [markdown]
# ### XGBoost

# %% [markdown]
# Next, we consider XGBoost for this forecasting task. The process is similar to that for linear regression. We first do an 8 week forecasting.

# %%
# Create feature and target dataframes
df_features = df_tab.copy()[[col for col in df_tab.columns if not (col in ['Year','Dengue_Count'])]]
df_target = df_tab.copy()[['Dengue_Count']]

# Define parameters for XGBoost
params = {
    'learning_rate': 0.1,
    'n_estimators': 1000,
    'max_depth': 8,
    'min_child_weight': 1,
    'gamma': 0.6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'reg_lambda': 1,
    'reg_alpha': 1,
    'objective': 'reg:squarederror',
    'random_state': 42,
    'device':'cuda',
    'tree_method':'hist'
}

# Split into train and test sets for a 8 week prediction
forecast_window = 8
tscv = TimeSeriesSplit(n_splits=68, test_size=forecast_window)

# Collect predictions
preds = []
for i, (train_ind,test_ind) in enumerate(tscv.split(df_features)):
    # Initialize XGBoost regressor with defined parameters
    model = xgb.XGBRegressor(**params)

    # Train the model
    model.fit(df_features.iloc[train_ind,:], df_target.iloc[train_ind])

    # Get prediction
    y_pred = get_sequential_predictions(model, df_features.iloc[test_ind,:],
                                    dict_target_lags=dict_target_lags)
    y_pred = pd.DataFrame(y_pred,columns=['Dengue_Count'],index=df_features.iloc[test_ind,:].index)
    preds.append(y_pred)

df_preds_xgb_8 = pd.concat(preds)
mae_xgb_8 = mean_absolute_error(df_target.loc[df_preds_xgb_8.index],df_preds_xgb_8)

# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(df_target,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_xgb_8,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_xgb_8.index[0], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'XGBoost Dengue Count Prediction, Forecast Window = 8 weeks, MAE = {mae_xgb_8:.1f}');

# %% [markdown]
# This gives an MAE of 87. Next we look at the performance of the XGBoost model for a 24 week (6 month) forecast window.

# %%
# Create feature and target dataframes
df_features = df_tab.copy()[[col for col in df_tab.columns if not (col in ['Year','Dengue_Count'])]]
df_target = df_tab.copy()[['Dengue_Count']]

# Define parameters for XGBoost
params = {
    'learning_rate': 0.1,
    'n_estimators': 1000,
    'max_depth': 8,
    'min_child_weight': 1,
    'gamma': 0.6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'reg_lambda': 1,
    'reg_alpha': 1,
    'objective': 'reg:squarederror',
    'random_state': 42,
    'device':'cuda',
    'tree_method':'hist'
}

# Split into train and test sets for a 24 week prediction
forecast_window = 24
tscv = TimeSeriesSplit(n_splits=23, test_size=forecast_window)

# Collect predictions
preds = []
for i, (train_ind,test_ind) in enumerate(tscv.split(df_features)):
    # Initialize XGBoost regressor with defined parameters
    model = xgb.XGBRegressor(**params)

    # Train the model
    model.fit(df_features.iloc[train_ind,:], df_target.iloc[train_ind])

    # Get prediction
    y_pred = get_sequential_predictions(model, df_features.iloc[test_ind,:],
                                    dict_target_lags=dict_target_lags)
    y_pred = pd.DataFrame(y_pred,columns=['Dengue_Count'],index=df_features.iloc[test_ind,:].index)
    preds.append(y_pred)

df_preds_xgb_24 = pd.concat(preds)
mae_xgb_24 = mean_absolute_error(df_target.loc[df_preds_xgb_24.index],df_preds_xgb_24)

# Plot
fig,ax = plt.subplots(1,1,figsize=(14,7))
ax.plot(df_target,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_xgb_24,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_xgb_24.index[0], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'XGBoost Dengue Count Prediction, Forecast Window = 24 weeks, RMSE = {mae_xgb_24:.1f}');

# %% [markdown]
# With a larger forecast window, the XGBoost model shows a higher error at MAE of 146.

# %% [markdown]
# ### Model Comparison

# %% [markdown]
# The performance of the three models for different forecast windows is shown in the plot below.

# %%
fig,axs = plt.subplots(2,3,figsize=(20,8))

axs[0,0].plot(target.iloc[108:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[0,0].plot(df_preds_sar_8,'r--',label='Predicted Dengue Counts')
# axs[0,0].axvline(x=df_preds_sar_8.index[108], color='k', linestyle='--', linewidth=1)
axs[0,0].legend()
axs[0,0].set_title(f'SARIMAX: 8 WEEK forecast, MAE = {mae_sar_8:.3f}');

axs[1,0].plot(target.iloc[100:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[1,0].plot(df_preds_sar_24,'r--',label='Predicted Dengue Counts')
# axs[1,0].axvline(x=df_preds_sar_24.index[100], color='k', linestyle='--', linewidth=1)
axs[1,0].legend()
axs[1,0].set_title(f'SARIMAX: 24 WEEK forecast, RMSE = {rmse_sar_24:.3f}, MAE = {mae_sar_24:.3f}');

axs[0,1].plot(target.iloc[108:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[0,1].plot(df_preds_lr_8,'r--',label='Predicted Dengue Counts')
# axs[0,1].axvline(x=df_preds_lr_8.index[108], color='k', linestyle='--', linewidth=1)
axs[0,1].legend()
axs[0,1].set_title(f'LINEAR: 8 WEEK forecast, MAE = {mae_lr_8:.3f}');

axs[1,1].plot(target.iloc[100:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[1,1].plot(df_preds_lr_24,'r--',label='Predicted Dengue Counts')
# axs[1,1].axvline(x=df_preds_lr_24.index[100], color='k', linestyle='--', linewidth=1)
axs[1,1].legend()
axs[1,1].set_title(f'LINEAR: 24 WEEK forecast, MAE = {mae_lr_24:.3f}');

axs[0,2].plot(target.iloc[108:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[0,2].plot(df_preds_xgb_8,'r--',label='Predicted Dengue Counts')
# axs[0,2].axvline(x=df_preds_xgb_8.index[108], color='k', linestyle='--', linewidth=1)
axs[0,2].legend()
axs[0,2].set_title(f'XGB: 8 WEEK forecast, MAE = {mae_xgb_8:.3f}');

axs[1,2].plot(target.iloc[100:],'b',label='Actual Dengue Counts',alpha=0.5)
axs[1,2].plot(df_preds_xgb_24,'r--',label='Predicted Dengue Counts')
# axs[1,2].axvline(x=df_preds_xgb_24.index[100], color='k', linestyle='--', linewidth=1)
axs[1,2].legend()
axs[1,2].set_title(f'XGB: 24 WEEK forecast, MAE = {mae_xgb_24:.3f}');

fig.tight_layout();

# %% [markdown]
# Based on the comparison above, we find that:
# 1. As expected, forecasts are more correct accurate when the forecast window is smaller.
# 2. For a forecast window of 8 weeks, all models show similar performance.
# 3. For a larger forecast window of 24 weeks, the XGBoost model performs the best, followed by the linear regression model and finally SARIMAX.
# 4. The XGBoost model additional shows lower levels of noise
# Considering its superior predictive power as shown above, we focus on XGBoost in the following analysis.

# %% [markdown]
# ## XGBoost Model Refinement

# %% [markdown]
# We refine the XGBoost model here by accounting for the uncertainty in input features. As with target values, we do not necessarily have foreknowledge of the features in the forecast window, especially for google search trends and weather conditions. For the evaluation below, we use mean historical values for these features. As Wolbachia efforts and external events (i.e. pandemic related lockdowns and heightened construction activities) are controlled by the authorities, we consider these as known values.

# %%
# Define lag characteristics
feature_lags = range(1, 6)
lagged_features = ['Daily_Rainfall', 'Mean_Temperature', 'Relative_Humidity',
                   'Max_Temperature', 'Min_Temperature', 'Min_Wind_Speed',
                   'Max_Wind_speed', 'Trend_Dengue', 'Trend_Dengue_Symptoms',
                   'Trend_Fever', 'Trend_Mosquito','Wolbachia_Ratio','External_Events']
weak_features = ['Daily_Rainfall', 'Mean_Temperature', 'Relative_Humidity',
                   'Max_Temperature', 'Min_Temperature', 'Min_Wind_Speed',
                   'Max_Wind_speed', 'Trend_Dengue', 'Trend_Dengue_Symptoms',
                   'Trend_Fever', 'Trend_Mosquito'] # Features for which historical mean values are taken in forecast window
target_lags = range(1, 6)

# %% [markdown]
# We train and evaluate the model on a 24 week forecast window to show model performance under these new conditions. To simulate a lack of future knowledge on weather and Google trends in the forecast window, we take the weekly historical mean as the value for each unknown feature.

# %%
preds = [] # Collect predictions

# Split into train and test sets for a 8 week prediction
forecast_window = 24
tscv = TimeSeriesSplit(n_splits=23, test_size=forecast_window)

for train_ind, test_ind in tscv.split(df_raw):
    all_ind = np.hstack([train_ind, test_ind])
    df_tab = df_raw.copy().iloc[all_ind,:]

    # Prep train features with lagged features and target values
    X_train = df_tab.iloc[train_ind,:]        # Add feature lags
    for feat in lagged_features:
        for lag in feature_lags:
            X_train[f'{feat}_Lag_{lag}'] = X_train[feat].shift(lag)
    
    dict_target_lags = {}                     # Add target lags
    for lag in target_lags:
        dict_target_lags[lag] = f'Dengue_Count_Lag_{lag}'
        X_train[dict_target_lags[lag]] = X_train['Dengue_Count'].shift(lag)
    X_train = X_train[[col for col in X_train.columns if not (col in ['Year','Dengue_Count'])]]

    # Prep train labels
    y_train = df_tab.iloc[train_ind,:].loc[:,'Dengue_Count']

    # Get weekly historical mean of unknown features
    X_train_temp = df_tab.copy().iloc[train_ind,:]
    mean_feature_values = []
    for feat in weak_features:
        mean_feature_values.append(X_train_temp[['Week',feat]].groupby('Week').mean())
    mean_feature_values = pd.concat(mean_feature_values,axis=1)

    # Replace test feature values with historical means
    df_w_mean = df_tab.copy().iloc[test_ind,:]
    df_w_mean.drop(columns=weak_features,inplace=True)
    df_w_mean = df_w_mean.merge(mean_feature_values,on='Week',how='left')
    df_w_mean = pd.concat([df_tab.copy().iloc[train_ind,:],df_w_mean],axis=0)
    
    for feat in lagged_features:             # Add lagged features
        for lag in feature_lags:
            df_w_mean[f'{feat}_Lag_{lag}'] = df_w_mean[feat].shift(lag)
    
    for lag in target_lags:                  # Add target lags
        df_w_mean[dict_target_lags[lag]] = df_w_mean['Dengue_Count'].shift(lag)
    
    # Get test features and labels
    X_test = df_w_mean[[col for col in df_w_mean.columns if not (col in ['Year','Dengue_Count'])]]
    X_test = X_test.iloc[test_ind,:]
    X_test = X_test[X_train.columns]           # Get test feature columns in the same order as train df

    # Train the model
    model = xgb.XGBRegressor(**params)
    model.fit(X_train,y_train)

    # Get prediction
    y_pred = get_sequential_predictions(model, X_test, dict_target_lags=dict_target_lags)
    y_pred = pd.DataFrame(y_pred,columns=['Dengue_Count'],index=df_features.iloc[test_ind,:].index)
    preds.append(y_pred)
    
df_preds_xgb = pd.concat(preds)
mae = mean_absolute_error(df_target.loc[df_preds_xgb.index],df_preds_xgb)

# Plot
fig,ax = plt.subplots(1,1,figsize=(8,5))
ax.plot(df_target,'b',label='Actual Dengue Counts',alpha=0.5)
ax.plot(df_preds_xgb,'r--',label='Predicted Dengue Counts')
ax.axvline(x=df_preds_xgb.index[0], color='k', linestyle='--', linewidth=1)
ax.legend()
ax.set_title(f'Dengue Count Prediction, Forecast Window = 24 weeks, MAE = {mae:.1f}')
# Out:
# Text(0.5, 1.0, 'Dengue Count Prediction, Forecast Window = 24 weeks, MAE = 147.2')

# %% [markdown]
# The refined model gives an MAE of 147 and decent predictive power over 24-week periods.

# %% [markdown]
# ## Wolbachia Effectiveness Investigation

# %% [markdown]
# Using the refined XGBoost model, we take a look at the predicted efficacy of the Wolbachia Project. To do this, we predict dengue counts for 24 weeks (6 months) after the end of our dataset assuming:
# 1.  zero Wolbachia efforts; and
# 2.  full Wolbachia efforts
#
# By comparing the prediction for these two scenarios, we can see the effect of the Wolbachia Project (as interpreted by our model).
#
# First, we retrain the model with the complete dataset.

# %%
df_tab = df_raw.copy()

# Prep train features with lagged features and target values
# Add feature lags
X_train = df_tab.copy()
for feat in lagged_features:
    for lag in feature_lags:
        X_train[f'{feat}_Lag_{lag}'] = X_train[feat].shift(lag)

# Add target lags
dict_target_lags = {}
for lag in target_lags:
    dict_target_lags[lag] = f'Dengue_Count_Lag_{lag}'
    X_train[dict_target_lags[lag]] = X_train['Dengue_Count'].shift(lag)
X_train = X_train[[col for col in X_train.columns if not (col in ['Year','Dengue_Count'])]]

# Prep train labels
y_train = df_tab.loc[:,'Dengue_Count']

# Train the model
model = xgb.XGBRegressor(**params)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.6, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# We assume no knowledge of future weather conditions nor Google trends. The features reflecting these conditions are prepped below.

# %%
# Get weekly historical mean of unknown features
X_train_temp = df_tab.copy()
mean_feature_values = []
for feat in weak_features:
    mean_feature_values.append(X_train_temp[['Week',feat]].groupby('Week').mean())
mean_feature_values = pd.concat(mean_feature_values,axis=1)

# Create new prediction dataset with 24 additional weeks for prediction
last_date = df_tab.index[-1]                                                                # Get index of final week in dataframe
new_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=forecast_window, freq='W')           # Create dates for the forecast window required
df_w_mean = pd.DataFrame(index=new_dates)
df_w_mean['Year'] = df_w_mean.index.isocalendar().year                                      # Create year and month columns for later merging with historical mean df
df_w_mean['Week'] = df_w_mean.index.isocalendar().week
index_or = df_w_mean.index
df_w_mean = df_w_mean.merge(mean_feature_values,on='Week',how='left')
df_w_mean.set_index(index_or, inplace=True)
df_w_mean = pd.concat([df_tab.copy(),df_w_mean],axis=0)

# %% [markdown]
# As mentioned earlier, we predict expected dengue fever cases if Wolbachia efforts are in full force over the next 24 weeks...

# %%
# Predict for case with Wolbachia at 100%
df_pred_w_wolb = df_w_mean.copy()
df_pred_w_wolb.iloc[-forecast_window:,:].loc[:,'External_Events'] = 0
df_pred_w_wolb.iloc[-forecast_window:,:].loc[:,'Wolbachia_Ratio'] = 1

# Add lagged features
for feat in lagged_features:
    for lag in feature_lags:
        df_pred_w_wolb[f'{feat}_Lag_{lag}'] = df_pred_w_wolb[feat].shift(lag)
        
# Add target lags
for lag in target_lags:
    df_pred_w_wolb[dict_target_lags[lag]] = df_pred_w_wolb['Dengue_Count'].shift(lag)

# Get test features and labels
X_test = df_pred_w_wolb[[col for col in df_pred_w_wolb.columns if not (col in ['Year','Dengue_Count'])]]
X_test = X_test.iloc[-forecast_window:,:]
X_test = X_test[X_train.columns]           # Get test feature columns in the same order as train df

y_pred_w_wolb = get_sequential_predictions(model, X_test, dict_target_lags=dict_target_lags)
y_pred_w_wolb = pd.DataFrame(y_pred_w_wolb,columns=['Dengue_Count'],index=X_test.index)

# %% [markdown]
# ... and if Wolbachia efforts are halted altogether.

# %%
# Predict for case with Wolbachia at 0%
forecast_window = 24
df_pred_wo_wolb = df_w_mean.copy()
df_pred_wo_wolb.iloc[-forecast_window:,:].loc[:,'External_Events'] = 0
df_pred_wo_wolb.iloc[-forecast_window:,:].loc[:,'Wolbachia_Ratio'] = 0

# Add lagged features
for feat in lagged_features:
    for lag in feature_lags:
        df_pred_wo_wolb[f'{feat}_Lag_{lag}'] = df_pred_wo_wolb[feat].shift(lag)
        
# Add target lags
for lag in target_lags:
    df_pred_wo_wolb[dict_target_lags[lag]] = df_pred_wo_wolb['Dengue_Count'].shift(lag)

# Get test features and labels
X_test = df_pred_wo_wolb[[col for col in df_pred_wo_wolb.columns if not (col in ['Year','Dengue_Count'])]]
X_test = X_test.iloc[-forecast_window:,:]
X_test = X_test[X_train.columns]           # Get test feature columns in the same order as train df

y_pred_wo_wolb = get_sequential_predictions(model, X_test, dict_target_lags=dict_target_lags)
y_pred_wo_wolb = pd.DataFrame(y_pred_wo_wolb,columns=['Dengue_Count'],index=X_test.index)

# %% [markdown]
# The difference in expected dengue cases are shown below.

# %%
# Plot
fig,ax = plt.subplots(1,1,figsize=(10,5))
ax.plot(y_train.iloc[-20:],'b',label='Past Dengue Counts',alpha=0.5)
ax.plot(y_pred_w_wolb,'g',label='Predicted Dengue Counts WITH Wolbachia')
ax.plot(y_pred_wo_wolb,'r--',label='Predicted Dengue Counts WITHOUT Wolbachia')
ax.legend()
ax.set_title(f'Dengue Count Prediction, Forecast Window = {forecast_window} weeks')
# Out:
# Text(0.5, 1.0, 'Dengue Count Prediction, Forecast Window = 24 weeks')

# %% [markdown]
# As shown above, if Wolbachia efforts are stopped, the effects will not be felt immediately but will continue to grow over time.

# %% [markdown]
# ## Conclusion and Future Work

# %% [markdown]
# In this report, we have considered three predictive models for the dengue forecasting task at hand, namely SARIMAX, linear regression, and XGBoost. The models were built on a dataset gathered for this project, consisting of historical weather information, Google search trends, as well as Wolbachia coverage and external events. Additional efforts are spent to create lagged feature and target values for the second and third model, as data order is not automatically accounted for. Of these, XGBoost stands out as the best performing model as measured by the Mean Absolute Error (MAE). A refined XGBoost model is then used to investigate the effects of the Wolbachia Project, showing clear signs of increased dengue occurences in its absence. It is therefore recommended that Wolbachia efforts be continued and strengthened if possible.
#
# The models can be improved first and foremost by augmenting dataset with additional features, including:
# 1. Normalized Diffference Vegetation Index (NDVI), which measures vegetation cover known to be associated with dengue incidence rates;
# 2. Dominant dengue virus serotypes, e.g. serotype 1 (DENV-1) is associated with the rise of dengue cases towards the end of 2023
# 3. Other public health intervention programs, on top of Wolbachia
#
# Additionally, other models, such as Recurrent Neural Networks (RNNs) designed for sequential data, can be explored and evaluated. A model with more granularity can also be considered, for example, by incorporating geographical data and dengue fever counts specific to certain locations. Given the significant human and economic impact of this endemic disease, a well-crafted predictive model will undoubtedly be worthwhile.
